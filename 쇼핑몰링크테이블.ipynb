# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_shopping_mall_link_export_2025-03-11_102542.csv')
pb_df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_product_export_2025-03-11_114216.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4953 entries, 0 to 4952
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               4953 non-null   int64
#  1   fk_product_id    4953 non-null   int64
#  2   fk_pharmacy_ids  4953 non-null   object
#  3   shop_url         4953 non-null   object
#  4   del_yn           4953 non-null   object
#  5   reg_dt           4953 non-null   object
#  6   upd_dt           0 non-null      float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 271.0+ KB

# %%
df['shop_url'].value_counts()
# Out:
# shop_url
# 27550                                                          180
# https://store.kakao.com/befpharm/products/327161583              8
# https://store.kakao.com/befpharm/products/327161657              7
# https://store.kakao.com/befpharm/products/415746224              5
# https://store.kakao.com/befpharm/products/418447872              5
#                                                               ...
# https://store.kakao.com/starpharm/products/340915198             1
# https://store.kakao.com/starpharm/products/343386517             1
# https://store.kakao.com/starpharm/products/343383217             1
# https://store.kakao.com/starpharm/products/342062748             1
# https://closure.store.friendly-pharmacist.com/closure/50455      1
# Name: count, Length: 3960, dtype: int64

# %%
df.loc[df['shop_url'] == '27550', 'reg_dt'].max()
# Out:
# '2024-09-20 04:45:02.686097'

# %%
df['del_yn'].value_counts()
# Out:
# del_yn
# N    4053
# Y     900
# Name: count, dtype: int64

# %%
df[df['fk_pharmacy_ids'].str.contains('99999')]
# Out:
#         id  fk_product_id fk_pharmacy_ids  \
# 34    4890          35563         [99999]
# 37    4893          35454         [99999]
# 463   4962          35506         [99999]
# 1381  4998          35585         [99999]
# 1740  5034          35585         [99999]
# 2916  3296          35450         [99999]
# 2930  3297          35462         [99999]
# 2980  3368          35450         [99999]
# 2999  3441          35462         [99999]
# 3045  3440          35450         [99999]
# 3168  3554      417635046         [99999]
# 3202  3590      417635046         [99999]
# 3234  3626          35470         [99999]
# 3773  4165          25118         [99999]
# 3774  4166          24271         [99999]
# 3775  4167          25123         [99999]
# 3776  4168          25717         [99999]
# 3777  4169          26214         [99999]
# 3778  4170          26215         [99999]
# 3779  4171          26671         [99999]
# 3780  4172          26759         [99999]
# ...

# %%
pb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30891 entries, 0 to 30890
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        30891 non-null  int64
#  1   product_id                30891 non-null  object
#  2   crawling_group_name       30891 non-null  object
#  3   from_flag                 30891 non-null  object
#  4   reg_dt                    30891 non-null  object
#  5   product_name              30891 non-null  object
#  6   detail_url                24989 non-null  object
#  7   rank_order                30891 non-null  int64
#  8   original_image_url        21493 non-null  object
#  9   image_url                 25352 non-null  object
#  10  price                     21491 non-null  float64
#  11  mobile_price              21491 non-null  float64
#  12  price_unit                21491 non-null  object
# ...

# %%
for col in pb_df.columns:
    con = pb_df[col] == 417635046
    if len(pb_df[con].index) >= 1:
        print(pb_df[con].index)

# %%
pb_df.loc[[11611, 22916, 22916]]
# Out:
#           id         product_id crawling_group_name from_flag  \
# 11611  34910       manual_34909               글루타치온    manual
# 22916  17305  naver_36064156783               글루타치온     naver
# 22916  17305  naver_36064156783               글루타치온     naver
#
#                            reg_dt                            product_name  \
# 11611  2024-05-13 01:22:14.667448                        YDY 퓨어 리포좀 글루타치온
# 22916  2023-01-20 04:52:42.056928  이집트산 로즈마리 추출물 복합물 분말 가루 비오틴 마리골드 글루타치온
# 22916  2023-01-20 04:52:42.056928  이집트산 로즈마리 추출물 복합물 분말 가루 비오틴 마리골드 글루타치온
#
#                                               detail_url  rank_order  \
# 11611  https://smartstore.naver.com/ydynutrition/prod...           1
# 22916  https://cr.shopping.naver.com/adcr.nhn?x=tIv9O...         441
# 22916  https://cr.shopping.naver.com/adcr.nhn?x=tIv9O...         441
#
#                                       original_image_url  \
# 11611                                                NaN
# ...
