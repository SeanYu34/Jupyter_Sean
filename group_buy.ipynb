# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

df_product = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_product_export_2024-12-18_175105.csv')
df_sales = pd.read_csv('/Users/seanyu_mac/Downloads/public_admin_group_buy_excel_order_export_2024-12-18_160135.csv')
# Out:
# /var/folders/wl/txjbcgld2sngchsc7txxqppm0000gp/T/ipykernel_52020/2773294886.py:6: DtypeWarning: Columns (2,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sales = pd.read_csv('/Users/seanyu_mac/Downloads/public_admin_group_buy_excel_order_export_2024-12-18_160135.csv')

# %%
df_product.head(3)
# Out:
#       id    product_id crawling_group_name from_flag  \
# 0  27554  manual_23521                  홍삼    manual
# 1  27316  manual_23283                  엽산    manual
# 2  26693  manual_22660                  기타    manual
#
#                        reg_dt                    product_name  \
# 0  2024-03-22 02:56:42.189148     정관장 활기력 JOY 자몽허니 20ml x 30병
# 1  2024-03-13 05:33:20.832323    Swanson, 엽산, 800mcg, 캡슐 250정
# 2  2023-12-07 23:52:39.787709  NOW Foods, 판크레아틴 2000, 캡슐 100정
#
#                                           detail_url  rank_order  \
# 0  https://brand.naver.com/kgcshop/products/76250...           1
# 1  https://kr.iherb.com/pr/swanson-folic-acid-800...           1
# 2  https://kr.iherb.com/pr/now-foods-pancreatin-2...           1
#
#   original_image_url                                          image_url  ...  \
# 0                NaN  https://d1r0f51o4pfsh8.cloudfront.net/crwal_pr...  ...
# 1                NaN  https://d1r0f51o4pfsh8.cloudfront.net/crwal_pr...  ...
# ...

# %%
df_sales.head(3)
# Out:
#       id  group_buy_id    order_no   order_ymd_hms  order_ymd  order_hour  \
# 0   2420             5  2218575254  20230911160935   20230911          16
# 1   2430             5  2218505841  20230911150034   20230911          15
# 2  26417            29  2258038541  20231016124656   20231016          12
#
#   order_status                 order_option  order_count  box_count  \
# 0    305 배송 완료  선택: 트루엔 리포좀 비타민C 3박스(150일분)          1.0          3
# 1    305 배송 완료  선택: 트루엔 리포좀 비타민C 3박스(150일분)          1.0          3
# 2    305 배송 완료         선택: 오큐클리어 3박스(30%할인)          1.0          3
#
#   order_person order_mapping_name  order_price is_valid invalid_reason  \
# 0          NaN      3박스 (총 150일분)        63000        Y            NaN
# 1          NaN      3박스 (총 150일분)        63000        Y            NaN
# 2          NaN       3박스 (총 3개월분)        94500        Y            NaN
#
#                        reg_dt                   upsert_dt  upsert_before
# ...

# %%
df_merge = pd.merge(df_product[['id', 'product_name']], df_sales, on='id', how='inner')
df_merge.head(3)
# Out:
#       id                        product_name  group_buy_id          order_no  \
# 0  27316        Swanson, 엽산, 800mcg, 캡슐 250정            30        2258941548
# 1  26693      NOW Foods, 판크레아틴 2000, 캡슐 100정            28  2023101717846941
# 2   4126  Nature's Way, 이노시톨, 500mg, 캡슐 100정             9  2023091248261531
#
#     order_ymd_hms  order_ymd  order_hour  order_status  \
# 0  20231017091400   20231017           9  204 결제 취소 완료
# 1  20231017084406   20231017           8          구매확정
# 2  20230912061728   20230912           6          배송완료
#
#                    order_option  order_count  box_count order_person  \
# 0       선택: 트루엔 초임계 알티지오메가3 1박스          1.0          1          NaN
# 1              옵션선택: 2.마그뮨 1개월분          1.0          2          NaN
# 2  제품선택: 02_비포락토100억 5개 +1개추가증정          1.0          5          NaN
#
#   order_mapping_name  order_price is_valid invalid_reason  \
# 0      1박스 (총 100일분)        69000        Y            NaN
# ...

# %%
df = pd.DataFrame(df_merge.groupby('product_name')['order_price'].sum())
df['name'] = df.index
df[df['name'].str.contains('더좋은 베리굿 빌베리')]
# Out:
#                           order_price                      name
# product_name
# 더좋은 베리굿 빌베리 700mg x 100정       153000  더좋은 베리굿 빌베리 700mg x 100정

# %%
df_merge
# Out:
#          id                                 product_name  group_buy_id  \
# 0     27316                 Swanson, 엽산, 800mcg, 캡슐 250정            30
# 1     26693               NOW Foods, 판크레아틴 2000, 캡슐 100정            28
# 2      4126           Nature's Way, 이노시톨, 500mg, 캡슐 100정             9
# 3     26696  NOW Foods, 아슈와간다, 표준화 추출물, 450mg, 베지 캡슐 90정            28
# 4     26697                              닥터에스더 리스펙타 질유산균            28
# ...     ...                                          ...           ...
# 4994   6093            튼튼닷컴 칼슘2 마그네슘1 비타민D 1000mg x 360정             5
# 4995  11149                   모비타 마더스 엽산 620 500mg x 90정            12
# 4996  11235                 WELLERS 바른 엠에스엠 770mg x 180정            12
# 4997  11249                  케이세라퓨틱스 조인트킹 690 mg x 120캡슐            12
# 4998  17628                            글루타치온 콜라겐 1박스 90정            20
#
#               order_no   order_ymd_hms  order_ymd  order_hour  order_status  \
# ...
