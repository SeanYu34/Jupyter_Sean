# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

df = pd.read_excel('/Users/seanyu_mac/Downloads/주문내역_2024-02-21~2025-02-21.xlsx')
df.columns
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['결제 번호', '상품 번호', '주문 번호', '결제 완료일', '주문 상태', '상품명', '옵션명', '수량', '정상가',
#        '판매가', '쿠폰 할인', '포인트 할인', '적립금', '정산가', '수령인명', '수령인 연락처', '구매자명',
#        '구매자 ID', '구매자 연락처', '주소', '우편번호', '배송 메모', '주문 확인일', '발주 요청일',
#        '배송 완료일', '구매 확정일', '배송택배사', '송장 번호', '배송비 정책', '배송비', '도서산간 배송비',
#        '취소 완료일', '판매자 취소일', '반품 요청일', '수거 요청일', '수거 완료일', '반품 완료일'],
#       dtype='object')

# %%
len(df.iloc[:, 3].unique().tolist())
# Out:
# 11

# %%
df.iloc[:, [3, 4, 5, 6, 7, 13, 14, 15, 16, 17, 18]]
# Out:
#                     결제 완료일 주문 상태                                          상품명  \
# 0  2025-02-21 10:47:28.904  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 1  2025-02-21 10:41:37.392  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 2  2025-02-21 10:41:13.594  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 3  2025-02-21 10:32:52.848  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 4  2025-02-21 10:27:33.056  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 5  2025-02-21 10:27:22.266  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 6  2025-02-21 10:15:34.478  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 7  2025-02-21 10:13:41.225  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 8  2025-02-21 10:12:42.924  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 9  2025-02-21 10:09:49.233  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# 10 2025-02-21 10:06:44.592  결제완료  [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
#
# ...

# %%
df.loc[df['구매자명'].isna(), '수령인 연락처']
# Out:
# 0     010-9086-9049
# 3     010-7254-3015
# 5     010-2093-2959
# 7     010-3847-4414
# 8     010-4323-1609
# 9     010-5553-5150
# 10    010-8530-7817
# Name: 수령인 연락처, dtype: object
