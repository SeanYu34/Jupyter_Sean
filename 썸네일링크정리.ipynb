# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/seanyu_mac/Downloads/상품 자동 등록 스크립트 - 라이브 스크립트.csv')
df
# Out:
#       컬렉션 product_id                                 판매기간  \
# 0    공동구매      26671  2025-02-28 00:00 ~ 2099-12-31 00:00
# 1    공동구매      26214  2025-02-28 00:00 ~ 2099-12-31 00:00
# 2    공동구매      34910  2025-02-28 00:00 ~ 2099-12-31 00:00
# 3    공동구매      34708  2025-02-28 00:00 ~ 2099-12-31 00:00
# 4    공동구매      25717  2025-02-28 00:00 ~ 2099-12-31 00:00
# ..    ...        ...                                  ...
# 994   NaN        NaN                                  NaN
# 995   NaN        NaN                                  NaN
# 996   NaN        NaN                                  NaN
# 997   NaN        NaN                                  NaN
# 998   NaN        NaN                                  NaN
#
#                                     상품명 기본옵션 판매옵션   약사님 배송비 정책   셀러정보 배송택배사  \
# 0    [스페셜할인코드/서울약사] 프로바이오 에스엘비(SLB) 1박스   있음   없음  서울약사     1원  파마브로스  한진택배
# 1          [스페셜할인코드/서울약사] 퓨어리포좀비타민C 1박스   있음   없음  서울약사     1원  파마브로스  한진택배
# ...

# %%
billberry_2_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/billberry_2_thumb.webp'
billberry_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/billberry_thumb.webp'
bq10_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/bq10_thumb.webp'
coral_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/coral_thumb.webp'
fullspec_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/fullspec_thumb.webp'
hemchul_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/hemchul_thumb.webp'
hyoso_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/hyoso_thumb.webp'
liber_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/liber_thumb.webp'
maduo_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/maduo_thumb.webp'
ocuclear_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/ocuclear_thumb.webp'
omega3_bq10_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/omega3_bq10_thumb.webp'
omega3_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/omega3_thumb.webp'
post_gx_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/post_gx_thumb.webp'
probio_slb_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/probio_slb_thumb.webp'
pure_cumin_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/pure_cumin_thumb.webp'
pyto_cumin_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/pyto_cumin_thumb.webp'
sunvitamin_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/sunvitamin_thumb.webp'
vitaminC_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/vitaminC_thumb.webp'
ydy_glu_thumb = 'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/ydy_glu_thumb.webp'

# %%
df.drop(df[df['상품명'].isna()].index, inplace=True)
# Out:
# 0      [스페셜할인코드/서울약사] 프로바이오 에스엘비(SLB) 1박스
# 1            [스페셜할인코드/서울약사] 퓨어리포좀비타민C 1박스
# 2           [스페셜할인코드/서울약사] 퓨어리포좀글루타치온 1박스
# 3             [스페셜할인코드/서울약사] 풀스펙멀티비타민 1박스
# 4            [스페셜할인코드/서울약사] 폴라초임계오메가3 1박스
#                       ...
# 588    [스페셜할인코드/뵤리약사] YDY 오큐클리어 1박스(1개월분)
# 589    [스페셜할인코드/약사임당] YDY 오큐클리어 1박스(1개월분)
# 590    [스페셜할인코드/위키약사] YDY 오큐클리어 1박스(1개월분)
# 591    [스페셜할인코드/릴리약사] YDY 오큐클리어 1박스(1개월분)
# 592    [스페셜할인코드/유이약사] YDY 오큐클리어 1박스(1개월분)
# Name: 상품명, Length: 593, dtype: object

# %%
new_datas = []
for data in datas:
    result = data.strip()
    new_datas.append(result)
    
df['product'] = new_datas

# %%
df['product'].unique().tolist()
# Out:
# ['프로바이오 에스엘비(SLB)',
#  '퓨어리포좀비타민C',
#  '퓨어리포좀글루타치온',
#  '풀스펙멀티비타민',
#  '폴라초임계오메가3',
#  '이뮨 빌베리',
#  '라이버 맥주효모',
#  '포스트바이오틱스gx',
#  '파이토 레드큐민',
#  '코랄칼마디K2',
#  '오큐클리어',
#  '액티브 헴철',
#  '썬비타민D3&K2',
#  '내몸에 효소가득',
#  '액티브비큐텐',
#  '마그듀오',
#  'YDY 퓨어 레드큐민 30포',
#  'YDY 폴라초임계오메가3 2',
#  '파이토알엑스 이뮨 빌베리 2',
#  '파이토알엑스 이뮨 빌베리',
#  '파이토알엑스 라이버 맥주효모',
#  'YDY 퓨어리포좀글루타치온',
#  'YDY 포스트바이오틱스GX',
#  'YDY 액티브헴철',
#  'YDY 썬비타민D3&K2(6',
#  'YDY 썬비타민D3&K2 (',
#  'YDY 풀스펙멀티비타민',
#  'YDY 내몸에 효소가득',
#  'YDY 파이토 레드큐민',
#  'YDY 프로바이오 에스엘비',
#  'YDY 코랄칼마디K2',
#  'YDY 퓨어리포좀비타민C',
#  'YDY 폴라초임계오메가3',
#  'YDY 오큐클리어',
#  'YDY 액티브비큐텐',
#  'YDY 마그듀오',
#  'YDY 코랄칼마디K2 박스(']

# %%
con_billberry_2_thumb = df['product'] == '파이토알엑스 이뮨 빌베리 2'
con_billberry_thumb = (df['product'] == '파이토알엑스 이뮨 빌베리') | (df['product'] == '이뮨 빌베리')
con_bq10_thumb = (df['product'] == '액티브비큐텐') | (df['product'] == 'YDY 액티브비큐텐')
con_coral_thumb = (df['product'] == '코랄칼마디K2') | (df['product'] == 'YDY 코랄칼마디K2 박스(') | (df['product'] == 'YDY 코랄칼마디K2')
con_fullspec_thumb = (df['product'] == '풀스펙멀티비타민') | (df['product'] == 'YDY 풀스펙멀티비타민')
con_hemchul_thumb = (df['product'] == '액티브 헴철') | (df['product'] == 'YDY 액티브헴철')
con_hyoso_thumb = (df['product'] == '내몸에 효소가득') | (df['product'] == 'YDY 내몸에 효소가득')
con_liber_thumb = (df['product'] == '라이버 맥주효모') | (df['product'] == '파이토알엑스 라이버 맥주효모')
con_maduo_thumb = (df['product'] == '마그듀오') | (df['product'] == 'YDY 마그듀오')
con_ocuclear_thumb = (df['product'] == '오큐클리어') | (df['product'] == 'YDY 오큐클리어')
con_omega3_bq10_thumb = df['product'] == 'YDY 폴라초임계오메가3 2'
con_omega3_thumb = (df['product'] == '폴라초임계오메가3') | (df['product'] == 'YDY 폴라초임계오메가3')
con_post_gx_thumb = (df['product'] == '포스트바이오틱스gx') | (df['product'] == 'YDY 포스트바이오틱스GX')
con_probio_slb_thumb = (df['product'] == '프로바이오 에스엘비(SLB)') | (df['product'] == 'YDY 프로바이오 에스엘비')
con_pure_cumin_thumb = df['product'] == 'YDY 퓨어 레드큐민 30포'
con_pyto_cumin_thumb = (df['product'] == 'YDY 파이토 레드큐민') | (df['product'] == '파이토 레드큐민')
con_sunvitamin_thumb = (df['product'] == '썬비타민D3&K2') | (df['product'] == 'YDY 썬비타민D3&K2(6') | (df['product'] == 'YDY 썬비타민D3&K2 (')
con_vitaminC_thumb = (df['product'] == '퓨어리포좀비타민C') | (df['product'] == 'YDY 퓨어리포좀비타민C')
con_ydy_glu_thumb = (df['product'] == '퓨어리포좀글루타치온') | (df['product'] == 'YDY 퓨어리포좀글루타치온') | (df['product'] == 'YDY 썬비타민D3&K2 (')

# %%
df.loc[con_billberry_2_thumb, 'thumb'] = billberry_2_thumb
df.loc[con_billberry_thumb, 'thumb'] = billberry_thumb
df.loc[con_bq10_thumb, 'thumb'] = bq10_thumb
df.loc[con_coral_thumb, 'thumb'] = coral_thumb
df.loc[con_fullspec_thumb, 'thumb'] = fullspec_thumb
df.loc[con_hemchul_thumb, 'thumb'] = hemchul_thumb
df.loc[con_hyoso_thumb, 'thumb'] = hyoso_thumb
df.loc[con_liber_thumb, 'thumb'] = liber_thumb
df.loc[con_maduo_thumb, 'thumb'] = maduo_thumb
df.loc[con_ocuclear_thumb, 'thumb'] = ocuclear_thumb
df.loc[con_omega3_bq10_thumb, 'thumb'] = omega3_bq10_thumb
df.loc[con_omega3_thumb, 'thumb'] = omega3_thumb
df.loc[con_post_gx_thumb, 'thumb'] = post_gx_thumb
df.loc[con_probio_slb_thumb, 'thumb'] = probio_slb_thumb
df.loc[con_pure_cumin_thumb, 'thumb'] = pure_cumin_thumb
df.loc[con_pyto_cumin_thumb, 'thumb'] = pyto_cumin_thumb
df.loc[con_sunvitamin_thumb, 'thumb'] = sunvitamin_thumb
df.loc[con_vitaminC_thumb, 'thumb'] = vitaminC_thumb
df.loc[con_ydy_glu_thumb, 'thumb'] = ydy_glu_thumb

# %%
df['thumb'].unique()
# Out:
# array(['https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/probio_slb_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/vitaminC_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/ydy_glu_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/fullspec_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/omega3_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/billberry_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/liber_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/post_gx_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/pyto_cumin_thumb.webp',
#        'https://img.friendly-pharmacist.com/Friendly_store/Thumbnails/coral_thumb.webp',
# ...

# %%
df.to_excel('/Users/seanyu_mac/Downloads/썸네일정리.xlsx')
