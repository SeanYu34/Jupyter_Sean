# %%
import pandas as pd

df = pd.read_excel('/Users/seanyu_mac/Downloads/product_20241119174029.xlsx')
df
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           상품번호  판매자상품코드                                         상품명 판매상태  \
# 0    447986760      NaN             [스페셜할인코드/하유약사] 트루엔 정직한 꼬소미 여주스틱  판매중
# 1    447986719      NaN            [스페셜할인코드/스마일약사] 트루엔 정직한 꼬소미 여주스틱  판매중
# 2    447986685      NaN             [스페셜할인코드/샤인약사] 트루엔 정직한 꼬소미 여주스틱  판매중
# 3    447986648      NaN             [스페셜할인코드/자신약사] 트루엔 정직한 꼬소미 여주스틱  판매중
# 4    447986592      NaN             [스페셜할인코드/쎄씨약사] 트루엔 정직한 꼬소미 여주스틱  판매중
# ..         ...      ...                                         ...  ...
# 214  423082807      NaN  [스페셜할인코드/자신약사] 더리틀스 케이투 폴리마그네슘부스터 1박스(60정)  판매중
# 215  423082752      NaN  [스페셜할인코드/샤인약사] 더리틀스 케이투 폴리마그네슘부스터 1박스(60정)  판매중
# 216  423082644      NaN  [스페셜할인코드/유이약사] 더리틀스 케이투 폴리마그네슘부스터 1박스(60정)  판매중
# ...

# %%
df['상품명'].unique()
# Out:
# array(['[스페셜할인코드/하유약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/스마일약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/샤인약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/자신약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/쎄씨약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/삐약약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/베이지약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/두둥실팜] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/쏘핏약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/애플약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/김약사TV] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/은하약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/배혜정약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/임상우약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/김민혜약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/이재연약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/딸기약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/몸짱약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/봄약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/남기헌약사] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/박약다식] 트루엔 정직한 꼬소미 여주스틱',
#        '[스페셜할인코드/쀼약사] 트루엔 정직한 꼬소미 여주스틱',
# ...
