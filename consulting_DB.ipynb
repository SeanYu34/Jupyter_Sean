# %% [markdown]
# 기간 : 2024년 1월 1일부터 - 현재까지
# 데이터 컬럼
# 기간 내 라이언 지정 상담 합계
# 가장 많이 상담 요청한 사용자 1-3위
# 닉네임
# 실명
# 가입일
# 상담 요청 건수 합계
# 기간 내 라이언 추가 상담 합계
# 가장 많이 추가 상담 요청한 사용자 1-3위
# 닉네임
# 실명
# 가입일
# 추가 상담 요청 건수 합계

# %%
import pandas as pd

df = pd.read_csv('/Users/seanyu_mac/Downloads/public_consulting_export_2024-11-12_105743.csv')
df.columns
# Out:
# /var/folders/wl/txjbcgld2sngchsc7txxqppm0000gp/T/ipykernel_1993/257516606.py:3: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/seanyu_mac/Downloads/public_consulting_export_2024-11-12_105743.csv')
# Index(['id', 'user_id', 'title', 'content', 'answer', 'referer', 'status',
#        'reg_id', 'reg_dt', 'upd_dt', 'del_yn', 'consulting_type',
#        'attached_image', 'youtube_video_id', 'answer_dt', 'review_score',
#        'profile_id', 'profile_answer', 'analysis_id', 'read_yn',
#        'related_video_id', 'public_request', 'public_yn', 'recommend_items',
#        'answer_type', 'answer_user_id', 'related_video_ids', 'del_dt',
#        'answer_pharmacy_id', 'update_user_type', 'admin_memo',
#        'recommend_product_ids', 'auto_complete_yn', 'referer_detail',
#        'pharmacy_check_request', 'confirm_dt', 'consulting_category',
# ...

# %%
df[df['pharmacy_title_code'] == 'anjaedon']
# Out:
#           id                               user_id                    title  \
# 14     29149  eb2c30f9-2ef2-4a5d-95ed-cdff91eebd51            영양제 조합 부탁드립니다
# 79     30257  ab36c63c-3cb2-430b-82ab-5b7d678ca8bd  선물받은 영양제 복용 관련 문의 드립니다!
# 856    24139  ae994774-e7ed-4b6f-a9fd-3c2310b9c06b                      테스트
# 2433   30332  b592386a-634b-4b21-9923-7c8edb28a16a          영양제 복용 문의드립니다.
# 2923   30322  0dcfe714-d394-4a8e-b8e2-1bf759c1933e                      테스트
# ...      ...                                   ...                      ...
# 32486  32377  85eb6abb-6ff5-4bcb-bbee-d5c01840c106                 영양제 복용문의
# 32492  32488  8c7a1551-29a1-4530-a357-6d5d3a23d661          영양제 추천 부탁드립니다.
# 32501  32595  970cc8da-e607-4aad-befb-5176838de56e                      테스트
# 32507  33155  cda3feed-e6ad-441b-99b3-742d4044b772              해독주스 문의드립니다
# 32511  33223  38bc08f5-c5cf-4c11-a781-e546689f4af5          허투양성 유방암 투병중입니다
#
# ...

# %%
referer_detail_list = df['referer_detail'].tolist()
temp_list = []

for i in referer_detail_list:
    if type(i) != str:
        temp_list.append('none')
    else:
        i = json.loads(i)
        temp_list.append(i)

temp_list
# Out:
# ['none',
#  'none',
#  {'keyName': ['title_code'],
#   'keyValue': ['star_pharmacy'],
#   'tableName': ['admin_link_page']},
#  'none',
#  'none',
#  'none',
#  {'keyName': ['title_code'],
#   'keyValue': ['wiki_yaksa'],
#   'tableName': ['admin_link_page']},
#  {'keyName': ['id'], 'keyValue': ['2260'], 'tableName': ['consulting_reply']},
#  'none',
#  'none',
#  {'keyName': ['title_code'],
#   'keyValue': ['star_pharmacy'],
#   'tableName': ['admin_link_page']},
#  'none',
#  {'keyName': ['id'], 'keyValue': ['1507'], 'tableName': ['consulting_reply']},
#  'none',
#  {'keyName': ['title_code'],
#   'keyValue': ['anjaedon'],
#   'tableName': ['admin_profile']},
#  {'keyName': ['title_code'],
#   'keyValue': ['iam_yaksa_'],
#   'tableName': ['admin_link_page']},
#  {'keyName': ['id'],
#   'keyValue': ['25'],
#   'tableName': ['product_show_category']},
#  'none',
#  {'keyName': ['title_code'],
#   'keyValue': ['yakstory119'],
#   'tableName': ['admin_profile']},
# ...
