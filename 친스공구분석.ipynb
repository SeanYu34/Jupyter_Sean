# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt
warnings.simplefilter('ignore')

# %%
df = pd.read_excel('/Users/seanyu_mac/Downloads/주문내역_2024-04-02~2025-04-02.xlsx')

ue_250325 = '[공동구매] 유이약사 X YDY 폴라초임계오메가3 /rTG 저온 초임계 / 3박스 6박스 12박스'
ssofit_250318 = '[공동구매] 쏘핏약사 x YDY 퓨어리포좀비타민C / 3박스 6박스 12박스'
jenny_250320 = '[공동구매] 몸짱약사 X YDY 오큐클리어 / 2박스 6박스'
mh_250319 = '[공동구매] 명훈약사 X YDY 퓨어리포좀글루타치온 / 3박스 6박스 12박스'
bbu_250318 = '[공동구매] 쀼약사 X YDY 마그듀오 / 4박스 8박스 12박스'
bicheck_250317 = '[공동구매] 약사비책 X YDY 프로바이오 에스엘비 / 2박스 4박스 6박스'
wiki_250221 = '[공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스'

gongu_list = [ue_250325, ssofit_250318, jenny_250320, mh_250319, bbu_250318, bicheck_250317, wiki_250221]

# %%
df = df[df['주문 상태'].isin(['결제완료', '배송중', '배송완료', '배송준비', '구매확정'])]

# %%
for i in gongu_list:
    con = df['상품명'] == i
    temp_df = df[con]
    arpu = np.round(temp_df['정산가'].mean(), 1)
    count = len(temp_df['결제 번호'].unique().tolist())
    print(f'{i}\narpu : {arpu:,}원\n주문건수 : {count:,}건')
# Out:
# [공동구매] 유이약사 X YDY 폴라초임계오메가3 /rTG 저온 초임계 / 3박스 6박스 12박스
# arpu : 119,498.8원
# 주문건수 : 256건
# [공동구매] 쏘핏약사 x YDY 퓨어리포좀비타민C / 3박스 6박스 12박스
# arpu : 114,901.4원
# 주문건수 : 209건
# [공동구매] 몸짱약사 X YDY 오큐클리어 / 2박스 6박스
# arpu : 135,681.8원
# 주문건수 : 44건
# [공동구매] 명훈약사 X YDY 퓨어리포좀글루타치온 / 3박스 6박스 12박스
# arpu : 140,756.1원
# 주문건수 : 41건
# [공동구매] 쀼약사 X YDY 마그듀오 / 4박스 8박스 12박스
# arpu : 118,209.3원
# 주문건수 : 43건
# [공동구매] 약사비책 X YDY 프로바이오 에스엘비 / 2박스 4박스 6박스
# arpu : 141,513.1원
# 주문건수 : 199건
# [공동구매] 위키약사 X YDY 포스트바이오틱스GX / 4박스 6박스 12박스
# arpu : 163,418.2원
# 주문건수 : 99건

# %%
df
# Out:
#                          결제 번호  상품 번호        주문 번호                  결제 완료일  \
# 0     parma202504020816190qLg4  50425  52133-51776 2025-04-02 08:16:39.762
# 1     parma202504020816190qLg4  50425  52133-51775 2025-04-02 08:16:39.762
# 2     parma202504012122170TNo2  50010  52132-51774 2025-04-01 21:25:42.241
# 3     parma202504011149179GYJ3  50040  52131-51773 2025-04-01 11:49:44.010
# 4     parma202503312342036XTK2  51182  52130-51772 2025-03-31 23:42:49.370
# ...                        ...    ...          ...                     ...
# 1432  parma20240928090515CkfQ2  50085  50016-50017 2024-09-28 09:05:13.391
# 1434  parma20240927134828DZU39  50006  50014-50015 2024-09-27 13:48:27.498
# 1437  parma20240926130234OzMz1  50012  50012-50012 2024-09-26 13:02:33.557
# 1443  parma20240925133216CVxv5  50009  50005-50005 2024-09-25 13:32:16.307
# 1445  parma20240920184127cDyU0  50000  50003-50003 2024-09-20 18:41:26.787
#
#      주문 상태                                                상품명  \
# ...
