# %%
import pandas as pd

df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_user_auth_info_export_2024-11-12_143442.csv')
df
# Out:
#                                         id                   email sns_type  \
# 0     130549b7-128f-46ee-991f-75b35bebfa55     lover0422@naver.com    kakao
# 1     ac9a1f0f-f9b6-490d-bf7f-1e53ac552a7a  twinyoung1@hanmail.net    kakao
# 2     65cf3524-98aa-43cd-950d-c6b1c0d8065a   joongeonpark@daum.net    kakao
# 3     af928778-068d-4c8b-80fb-94e84ee5fb6a     aladud369@naver.com    kakao
# 4     b76a46dc-cfbc-479a-8fd9-eec0cc891eda        ksh915@kakao.com    kakao
# ...                                    ...                     ...      ...
# 7408  dccec935-6703-4ace-93b3-a5af6144a8e3  sangmi980513@kakao.com    kakao
# 7409  ebd7b9f4-ab43-4e65-afa1-81d124afe48b       preze00@kakao.com    kakao
# 7410  81866f92-1aa0-4600-b374-bd937e795084    kangchangu@kakao.com    kakao
# 7411  48e02826-6f8f-4802-bee1-0af69955f17f    parkhr21@hanmail.net    kakao
# 7412  65bf4581-f9cd-4fce-b138-1266eca1ad89     lhj7046@hanmail.net    kakao
#
# ...

# %%
con = df['nickname'] == '박소희'
df[con]
# Out:
#                                         id               email sns_type  \
# 2358  8f60f773-24b4-48af-8aaf-29a5b2046958  thgml612@gmail.com    kakao
#
#           sns_id nickname name password  birthday       phone sex  ...  \
# 2358  3593684709      박소희  박소희      NaN  19950612  1065127862  여자  ...
#
#                                                      ci is_connect  \
# 2358  tS0yzgXXSORyUsfSqqNf52XZj6SNX13ySBdf6A3o1vYHlM...      False
#
#                    created_at               updated_at is_delete  deleted_at  \
# 2358  2024-08-16 02:00:34.633  2024-08-16 02:00:34.633     False         NaN
#
#       delete_reason                               user_id display_email  \
# 2358            NaN  55118a7d-6bad-4add-b82a-d302c6ac9b54           NaN
#
#                                                settings
# 2358  {"sms":{"value":false,"updated_at":"2024-08-16...
#
# [1 rows x 21 columns]
