# %%
import pandas as pd

df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_user_auth_info_export_2024-11-12_143442.csv')
df.index.size
# Out:
# 7413

# %%
from datetime import datetime, timedelta
con = df['sns_type'] == 'apple'
df['updated_at'] = pd.to_datetime(df['updated_at'], format='mixed')
con1 = df.loc[con, 'updated_at'] > datetime(2024, 10, 27)
df[con & con1]
# Out:
#                                         id  \
# 4296  f5e72523-e468-4ef6-8d0f-d4be5827f273
# 4351  2d0424bf-33c0-42bf-add0-582d999e0415
# 4473  25ef8094-8a1e-423f-b320-5cd6d499dfa8
# 4556  608ba315-765d-46dd-85c8-8646d65ccc38
# 4751  a28c2d15-fe20-4feb-89f8-476eee129b3e
# 4754  8a7c8ece-1fd6-4efe-aab2-6894cdff4d84
# 4769  39cafb31-2a20-4b65-913a-9dde8f93186a
# 4827  cda53f7b-b832-4426-b914-d9ef9cb2b818
# 4859  1ae94cbf-2770-4ad4-99a3-f5d2dc5889b6
# 4929  03547ae2-8c37-4b44-bb9d-a8e81275335c
# 5164  a013dcb4-52b8-4f5d-9724-9b4e7e911d39
# 5180  22ade1bd-fbd2-4859-afe1-970108d5d8e5
# 5247  f67d33e4-d568-4ad9-b600-5f9fd7837662
# 5375  2e111e26-a862-4e8f-8662-d7a7d9bf6045
# 5385  55a00382-9d6e-4c38-aef9-0cc25291346a
# 5447  f6a8ae6d-0286-4aef-aa5e-697372a7a61c
# 5623  45051f49-c300-45ad-8ef8-505d8d4e676b
# 5912  0c08cdb0-7bc9-4c85-9385-7330f8bbabb9
# 5960  5e2a7b1c-9f19-478a-bacf-974464abd479
# 6125  0b45fa71-8d80-402a-bab3-6825b57788af
# 6156  dd18e443-731d-4bfe-a4bc-208150fd62d0
# ...
