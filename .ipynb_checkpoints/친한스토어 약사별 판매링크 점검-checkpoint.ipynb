# %%
import pandas as pd

df = pd.read_csv('/Users/seanyu_mac/Downloads/[친한구매]약사별 판매링크 관리_친한스토어_250305 - 전체 (1).csv')
df
# Out:
#            판매몰   약사ID     셀러       상품코드  어드민ID        상품명     정상가     판매가  \
# 0    톡스토어-친한약사     20  고상온약사  333238087  25118       마그듀오  25,000  25,000
# 1    톡스토어-친한약사     20  고상온약사  333238344  24271     액티브비큐텐  35,000  35,000
# 2    톡스토어-친한약사     20  고상온약사  333238391  25123      오큐클리어  45,000  45,000
# 3    톡스토어-친한약사     20  고상온약사  333238485  25717  폴라초임계오메가3  28,000  28,000
# 4    톡스토어-친한약사     20  고상온약사  333238538  26214  퓨어리포좀비타민C  29,000  29,000
# ..         ...    ...    ...        ...    ...        ...     ...     ...
# 608  톡스토어-친한약사  99999   친한약사  450507057  35585     이뮨 빌베리  33,900  33,900
# 609  톡스토어-친한약사    109   하유약사  450116239  35506   라이버 맥주효모  28,000  22,900
# 610  톡스토어-친한약사    109   하유약사  450507421  35585     이뮨 빌베리  33,900  33,900
# 611  톡스토어-친한약사     74   형제약사  450116407  35506   라이버 맥주효모  28,000  22,900
# 612  톡스토어-친한약사     74   형제약사  450507743  35585     이뮨 빌베리  33,900  33,900
#
#     친한구매 할인율 친한구매 할인가                                                 링크  \
# 0         5%   23,750  https://closure.store.friendly-pharmacist.com/...
# 1         5%   33,250  https://closure.store.friendly-pharmacist.com/...
# 2         5%   42,750  https://closure.store.friendly-pharmacist.com/...
# 3         5%   26,600  https://closure.store.friendly-pharmacist.com/...
# 4         5%   27,550  https://closure.store.friendly-pharmacist.com/...
# ..       ...      ...                                                ...
# 608       5%   32,200  https://closure.store.friendly-pharmacist.com/...
# 609       5%   21,700  https://closure.store.friendly-pharmacist.com/...
# 610       5%   32,200  https://closure.store.friendly-pharmacist.com/...
# 611       5%   21,700  https://closure.store.friendly-pharmacist.com/...
# 612       5%   32,200  https://closure.store.friendly-pharmacist.com/...
#
#       할인금액
# 0    1,250
# 1    1,750
# 2    2,250
# 3    1,400
# 4    1,450
# ..     ...
# 608  1,700
# 609  1,200
# 610  1,700
# 611  1,200
# 612  1,700
#
# [613 rows x 12 columns]

# %%
product_nums = []

for i in df['링크']:
    product_num = i.split('/')[4].strip()
    product_nums.append(product_num)

df['product_num'] = product_nums

# %%
df
# Out:
#            판매몰   약사ID     셀러       상품코드  어드민ID        상품명     정상가     판매가  \
# 0    톡스토어-친한약사     20  고상온약사  333238087  25118       마그듀오  25,000  25,000
# 1    톡스토어-친한약사     20  고상온약사  333238344  24271     액티브비큐텐  35,000  35,000
# 2    톡스토어-친한약사     20  고상온약사  333238391  25123      오큐클리어  45,000  45,000
# 3    톡스토어-친한약사     20  고상온약사  333238485  25717  폴라초임계오메가3  28,000  28,000
# 4    톡스토어-친한약사     20  고상온약사  333238538  26214  퓨어리포좀비타민C  29,000  29,000
# ..         ...    ...    ...        ...    ...        ...     ...     ...
# 608  톡스토어-친한약사  99999   친한약사  450507057  35585     이뮨 빌베리  33,900  33,900
# 609  톡스토어-친한약사    109   하유약사  450116239  35506   라이버 맥주효모  28,000  22,900
# 610  톡스토어-친한약사    109   하유약사  450507421  35585     이뮨 빌베리  33,900  33,900
# 611  톡스토어-친한약사     74   형제약사  450116407  35506   라이버 맥주효모  28,000  22,900
# 612  톡스토어-친한약사     74   형제약사  450507743  35585     이뮨 빌베리  33,900  33,900
#
#     친한구매 할인율 친한구매 할인가                                                 링크  \
# 0         5%   23,750  https://closure.store.friendly-pharmacist.com/...
# 1         5%   33,250  https://closure.store.friendly-pharmacist.com/...
# 2         5%   42,750  https://closure.store.friendly-pharmacist.com/...
# 3         5%   26,600  https://closure.store.friendly-pharmacist.com/...
# 4         5%   27,550  https://closure.store.friendly-pharmacist.com/...
# ..       ...      ...                                                ...
# 608       5%   32,200  https://closure.store.friendly-pharmacist.com/...
# 609       5%   21,700  https://closure.store.friendly-pharmacist.com/...
# 610       5%   32,200  https://closure.store.friendly-pharmacist.com/...
# 611       5%   21,700  https://closure.store.friendly-pharmacist.com/...
# 612       5%   32,200  https://closure.store.friendly-pharmacist.com/...
#
#       할인금액 product_num
# 0    1,250       50023
# 1    1,750       50022
# 2    2,250       51101
# 3    1,400       50021
# 4    1,450       51100
# ..     ...         ...
# 608  1,700       50617
# 609  1,200       50651
# 610  1,700       50616
# 611  1,200       50650
# 612  1,700       50615
#
# [613 rows x 13 columns]

# %%
for i in df['상품명'].unique():
    con = df['상품명'] == i
    price_list = df.loc[con, '정상가'].tolist() 
    for j in price_list:
        if j != price_list[0]:
            print(f'{i} 상품명 제품 중 {j} 원은 잘못된 정보입니다.')
# Out:
# 이뮨 빌베리 상품명 제품 중 82,000 원은 잘못된 정보입니다.

# %%
con1 = df['상품명'] == '이뮨 빌베리'
con2 = df['정상가'] == '82,000'
df[con1 & con2]
# Out:
#            판매몰  약사ID    셀러       상품코드 어드민ID     상품명     정상가     판매가 친한구매 할인율  \
# 596  톡스토어-친한약사    51  유이약사  461171902     -  이뮨 빌베리  82,000  62,900       6%
#
#     친한구매 할인가                                                 링크   할인금액  \
# 596   59,040  https://closure.store.friendly-pharmacist.com/...  3,860
#
#      product_num
# 596        50614
