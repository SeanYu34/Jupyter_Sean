# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# 카카오톡스토어의 상품 리스트를 다운로드
df = pd.read_excel('/Users/seanyu_mac/Downloads/product_20250226101648.xlsx')
# 현재 판매중인 건들만 필터링
df = df[df['판매상태'] == '판매중']
# 약사별 판매링크 아닌 공동구매 건들 필터링
df.drop(df[df['상품명'].str.contains('공동구매')].index, inplace=True)
# 약사별 판매링크 아닌 것들은 필터링
df.drop(df[df['상품명'].str.contains(']') == False].index, inplace=True)
# 중복된 건 필터링 : 풀스펙멀티비타민 친약, 친한약사
df.drop(df[df['상품번호'] == 373500859].index, inplace=True)
df.reset_index(drop=True, inplace=True)


pb_df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_product_export_2025-02-26_102450.csv')
pb_df.drop(pb_df[pb_df['product_id'].str.contains('naver')].index, inplace=True)
pb_df.drop(401, inplace=True)

# 친한스토어 상품 등록 시, 필요한 정보
# product_id, 컬렉션, 판매기간, 상품명, 기본옵션, 판매옵션, 배송비 정책, 배송택배사, 출고지, 반품/교환 택배사, 반품/교환지, 썸네일, 상세 이미지, 고시 이미지, 상품상태, 원산지, 영수증 발행여부, 제품명, 식품의 유형, 생산지 및 소재지, 제조연월일 소비기한 또는 품질 유지기한, 포장단위별 내용량의 용량(중량) 수량, 원재료명 및 함량, 영양성분, 유전자변형식품에 해당, 소비자안전을 위한 주의사항, 수입식품에 해당
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
product_link = {}
yaksa_names = []
product_names = []

for i in df['상품명'].unique():
    product_name = i.split(']')[1].strip()
    product_names.append(product_name)
    yaksa_name1 = i.split(']')[0].strip()
    yaksa_name2 = yaksa_name1.split('/')[1].strip()
    yaksa_names.append(yaksa_name2)

idx = sorted(list(set(product_names)))

# %%
ids = []

for i in idx:
    i = i.split()
    i = i[0] + ' ' + i[1]
    if '(' in i:
        i = i.split('(')[0]
    elif '1박스' in i:
        i = i.split('1박스')[0]
    ids.append(i)

for i in range(len(ids)):
    if '썬비타민' in ids[i]:
        ids[i] = 'YDY 썬 비타민'
    elif '코랄칼마디' in ids[i]:
        ids[i] = '코랄칼마디 K2'
    elif '포스트바이오틱스' in ids[i]:
        ids[i] = 'YDY 포스트바이오틱스 GX'
    elif '풀스펙멀티비타민' in ids[i]:
        ids[i] = 'YDY 풀스펙 멀티비타민'
    elif '퓨어리포좀글루타치온' in ids[i]:
        ids[i] = 'YDY 퓨어 리포좀 글루타치온'
    elif '퓨어리포좀비타민' in ids[i]:
        ids[i] = 'YDY 퓨어 리포좀 비타민C'
    elif '액티브 헴철' in ids[i]:
        ids[i] = 'YDY 액티브헴철'
    elif '액티브비큐텐' in ids[i]:
        ids[i] = 'YDY 액티브비큐텐'
    elif '오큐클리어' in ids[i]:
        ids[i] = 'YDY 오큐클리어'
    elif '폴라초임계오메가3' in ids[i]:
        ids[i] = 'YDY 폴라초임계오메가3'
    elif '마그듀오' in ids[i]:
        ids[i] = 'YDY 마그듀오'

# %%
pb_name_idx = []

for i in ids:
    con = pb_df['product_name'].str.contains(i)
    pb_name_idx.append(pb_df.loc[con, 'product_name'].values[0])

# %%
keys = range(0, len(df.columns.tolist()))
values = df.columns.tolist()
dict = dict(zip(keys, values))

# %%
result_df = pd.DataFrame()
txt = 'product_id, 컬렉션, 판매기간, 상품명, 기본옵션, 판매옵션, 약사님, 배송비 정책, 배송택배사, 출고지, 반품/교환 택배사, 반품/교환지, 썸네일, 상세 이미지, 고시 이미지, 상품상태, 원산지, 영수증 발행여부, 제품명, 식품의 유형, 생산지 및 소재지, 제조연월일 소비기한 또는 품질 유지기한, 포장단위별 내용량의 용량(중량) 수량, 원재료명 및 함량, 영양성분, 유전자변형식품에 해당, 소비자안전을 위한 주의사항, 수입식품에 해당'
txt = txt.split(',')
txts = []

for i in txt:
    txts.append(i.strip())

for i in txts:
    result_df[i] = 0

# %%
data = []
for i in range(630):
    data.append('공동구매')
result_df['컬렉션'] = data 

data = []
for i in range(630):
    data.append('2025-02-28 ~ 2099-12-31')
result_df['판매기간'] = data

data = []
for i in range(630):
    data.append('2025-02-28 ~ 2099-12-31')
result_df['판매기간'] = data

result_df['상품명'] = df['상품명']
result_df['배송비 정책'] = '무료배송'
result_df['배송택배사'] = '파마브로스'
result_df['배송택배사'] = '파마브로스'
result_df['출고지'] = '파마브로스'
result_df['반품/교환 택배사'] = '파마브로스'
result_df['반품/교환지'] = '파마브로스'
result_df['상품상태'] = '새상품'
result_df['원산지'] = '국내산'
result_df['영수증 발행여부'] = '신용카드/현금영수증 발급'

# %%
result_df['수입식품에 해당'] = '해당없음'

for i in ['제품명',
 '식품의 유형',
 '생산지 및 소재지',
 '제조연월일 소비기한 또는 품질 유지기한',
 '포장단위별 내용량의 용량(중량) 수량',
 '원재료명 및 함량',
 '영양성분',
 '유전자변형식품에 해당',
 '소비자안전을 위한 주의사항'
 ]:
    result_df[i] = '상품상세설명 참조'

# %%
yaksas = []

for i in result_df['상품명']:
    i = i.split(']')[0]
    i = i.split('/')[1]
    yaksas.append(i.strip())

result_df['약사님'] = yaksas

# %%
result_df.loc[result_df['약사님'] == '배혜정약사', '약사님'] = '우리약사'
result_df.loc[result_df['약사님'] == '김약사tv', '약사님'] = '김미성약사'
result_df.loc[result_df['약사님'] == '김약사TV', '약사님'] = '김미성약사'
result_df.loc[result_df['약사님'] == '친한', '약사님'] = '친한약사'

# %%
result_df.loc[:, '판매옵션'] = '없음'
# Out:
# /var/folders/wl/txjbcgld2sngchsc7txxqppm0000gp/T/ipykernel_82813/1236317530.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '없음' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.loc[:, '판매옵션'] = '없음'

# %%
result_df
# Out:
#      product_id   컬렉션                     판매기간  \
# 0           NaN  공동구매  2025-02-28 ~ 2099-12-31
# 1           NaN  공동구매  2025-02-28 ~ 2099-12-31
# 2           NaN  공동구매  2025-02-28 ~ 2099-12-31
# 3           NaN  공동구매  2025-02-28 ~ 2099-12-31
# 4           NaN  공동구매  2025-02-28 ~ 2099-12-31
# ..          ...   ...                      ...
# 625         NaN  공동구매  2025-02-28 ~ 2099-12-31
# 626         NaN  공동구매  2025-02-28 ~ 2099-12-31
# 627         NaN  공동구매  2025-02-28 ~ 2099-12-31
# 628         NaN  공동구매  2025-02-28 ~ 2099-12-31
# 629         NaN  공동구매  2025-02-28 ~ 2099-12-31
#
#                                     상품명  기본옵션 판매옵션   약사님 배송비 정책  배송택배사    출고지  \
# 0    [스페셜할인코드/서울약사] 프로바이오 에스엘비(SLB) 1박스   NaN   없음  서울약사   무료배송  파마브로스  파마브로스
# 1          [스페셜할인코드/서울약사] 퓨어리포좀비타민C 1박스   NaN   없음  서울약사   무료배송  파마브로스  파마브로스
# 2         [스페셜할인코드/서울약사] 퓨어리포좀글루타치온 1박스   NaN   없음  서울약사   무료배송  파마브로스  파마브로스
# 3           [스페셜할인코드/서울약사] 풀스펙멀티비타민 1박스   NaN   없음  서울약사   무료배송  파마브로스  파마브로스
# 4          [스페셜할인코드/서울약사] 폴라초임계오메가3 1박스   NaN   없음  서울약사   무료배송  파마브로스  파마브로스
# ..                                  ...   ...  ...   ...    ...    ...    ...
# 625  [스페셜할인코드/약사임당] YDY 오큐클리어 1박스(1개월분)   NaN   없음  약사임당   무료배송  파마브로스  파마브로스
# 626  [스페셜할인코드/위키약사] YDY 오큐클리어 1박스(1개월분)   NaN   없음  위키약사   무료배송  파마브로스  파마브로스
# 627  [스페셜할인코드/릴리약사] YDY 오큐클리어 1박스(1개월분)   NaN   없음  릴리약사   무료배송  파마브로스  파마브로스
# 628  [스페셜할인코드/유이약사] YDY 오큐클리어 1박스(1개월분)   NaN   없음  유이약사   무료배송  파마브로스  파마브로스
# 629    [스페셜할인코드/친한] YDY 오큐클리어 1박스(1개월분)   NaN   없음  친한약사   무료배송  파마브로스  파마브로스
#
#      ...        제품명     식품의 유형  생산지 및 소재지  제조연월일 소비기한 또는 품질 유지기한  \
# 0    ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 1    ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 2    ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 3    ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 4    ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# ..   ...        ...        ...        ...                    ...
# 625  ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 626  ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 627  ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 628  ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
# 629  ...  상품상세설명 참조  상품상세설명 참조  상품상세설명 참조              상품상세설명 참조
#
#      포장단위별 내용량의 용량(중량) 수량  원재료명 및 함량       영양성분 유전자변형식품에 해당 소비자안전을 위한 주의사항  \
# 0               상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 1               상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 2               상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 3               상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 4               상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# ..                    ...        ...        ...         ...            ...
# 625             상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 626             상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 627             상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 628             상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
# 629             상품상세설명 참조  상품상세설명 참조  상품상세설명 참조   상품상세설명 참조      상품상세설명 참조
#
#     수입식품에 해당
# 0       해당없음
# 1       해당없음
# 2       해당없음
# 3       해당없음
# 4       해당없음
# ..       ...
# 625     해당없음
# 626     해당없음
# 627     해당없음
# 628     해당없음
# 629     해당없음
#
# [630 rows x 28 columns]

# %%
pb_nums = []

for i in ids:
    con = pb_df['product_name'].str.contains(i)
    pb_nums.append(pb_df.loc[con, 'id'].values[0])

# %%
len(ids)
len(pb_nums)
# Out:
# [27487,
#  25118,
#  35514,
#  35514,
#  24271,
#  35450,
#  25123,
#  35713,
#  35713,
#  35713,
#  26759,
#  35462,
#  25717,
#  25717,
#  34708,
#  35629,
#  34910,
#  26214,
#  26671,
#  27487,
#  35506,
#  25118,
#  35514,
#  35450,
#  24271,
#  25123,
#  35585,
#  35713,
#  26759,
#  35506,
#  35585,
#  35585,
#  35462,
#  25717,
#  34708,
#  34910,
#  26214,
#  26671]
