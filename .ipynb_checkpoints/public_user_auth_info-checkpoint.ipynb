# %%
import pandas as pd

df = pd.read_csv('/Users/seanyu_mac/Downloads/public_pb_user_auth_info_export_2024-11-12_143442.csv')
df.index.size
# Out:
# 7413

# %%
from datetime import datetime, timedelta
con = df['sns_type'] == 'apple'
df['updated_at'] = pd.to_datetime(df['updated_at'], format='mixed')
con1 = df.loc[con, 'updated_at'] > datetime(2024, 9, 27)
df[con & con1]
# Out:
#                                         id  \
# 35    8e5a2517-7c68-4eed-b77a-a5ae48b876f0
# 4243  b5ebff0f-7605-407b-a288-e602bdb8a07c
# 4296  f5e72523-e468-4ef6-8d0f-d4be5827f273
# 4325  05df64d6-2b72-46e2-a82a-6e17d5ba36cd
# 4351  2d0424bf-33c0-42bf-add0-582d999e0415
# ...                                    ...
# 7384  b7703a74-818e-44f9-9431-4895e53bc990
# 7400  6d1539a5-3466-4ab5-9f9d-e88632ff7f69
# 7402  760b77a9-2b84-499e-9dbf-d296c37462fe
# 7404  d37be170-6b2a-4a27-9b95-2be8a61a936b
# 7406  f299d817-ac9e-419c-bed3-d8d0796b9f92
#
#                                     email sns_type  \
# 35    x8n8dtq5jh@privaterelay.appleid.com    apple
# 4243  gf8tvxd45f@privaterelay.appleid.com    apple
# 4296  hzqkxkbccr@privaterelay.appleid.com    apple
# 4325  dk5ykxcjnh@privaterelay.appleid.com    apple
# 4351  dhgvmr6rdq@privaterelay.appleid.com    apple
# ...                                   ...      ...
# 7384  44g5cvfbp9@privaterelay.appleid.com    apple
# 7400  6bqbxdnmtc@privaterelay.appleid.com    apple
# 7402                 dhsrudal@hanmail.net    apple
# 7404  xxf6wxqsr7@privaterelay.appleid.com    apple
# 7406           goodmanchoiyunho@gmail.com    apple
#
#                                             sns_id     nickname name password  \
# 35    001532.85c0946d54a04418b9672c3505efdba7.1216    순박한운석4669  박용준      NaN
# 4243  001695.e76afc19324842e2b713a3234a1d2916.1607          밤꼬마  최용준      NaN
# 4296  001868.0f8bb89ae0c949e895d6ad30e0ac2954.0157  너그러운부엉이6467  김영훈      NaN
# 4325  000723.2653284c5a3e464c8cc8bd91714e28e7.1140   재미있는현자7242  김채리      NaN
# 4351  002010.b242bcbcd23043e08d3eb569bc9218a5.0759    찬란한하늘0159  전미애      NaN
# ...                                            ...          ...  ...      ...
# 7384  000229.34cd610d014d4e9cb6453a93c4a7de7e.1429         aena  주서연      NaN
# 7400  000233.f0f61ec719804914ac32c53f642106bb.1613   온화한멋쟁이1383  김서연      NaN
# 7402  000631.dd2cbe773cf749578db476866a070a02.0930    순박한무사0134  온경미      NaN
# 7404  001796.a05060aedeb84eb39b9a64da2fdd59c9.0754    당당한초록3172  권주연      NaN
# 7406  000110.cd0b5692e570418e989441b746e21550.2138    화목한미인1835  최윤호      NaN
#
#       birthday       phone sex  ...  \
# 35    19920221  1041679202  남자  ...
# 4243  19960903  1048802294  남자  ...
# 4296  19771002  1063147930  남자  ...
# 4325  20090819  1089651170  여자  ...
# 4351  19940902  1049398497  여자  ...
# ...        ...         ...  ..  ...
# 7384  20010212  1050279923  여자  ...
# 7400  19960724  1048911992  여자  ...
# 7402  19840923  1026368495  여자  ...
# 7404  19981014  1077972396  여자  ...
# 7406  19751221  1074627451  남자  ...
#
#                                                      ci is_connect  \
# 35    2P06Jq0BrOFY4vC9vjOoF66U1tmCpfrE80kbuY/lYlECRX...      False
# 4243  iVFHiU4XKuAkZLx4pt4P2zfFgdM2v6X+Tz884C5v7AOwUz...      False
# 4296  SgzVuqm1tFJ4jekru3QJCQ/VXjU1oKYCm2dv3BiwaOyf6b...      False
# 4325  hNxe0rxtb8RR/CsLIJx+r9GSP9/tEAxurdQ/iF4nuT2aTV...      False
# 4351  DT3ZFzY2Bzg3ueD5o4wq4dSdRAlIW5mBC7a5oP7vY8BWdI...      False
# ...                                                 ...        ...
# 7384  mt/nQhNRh2PAjHwGl2RxGIQ2szdNky3XZMh3NP9qcN4xn8...      False
# 7400  5J/9Ae4A7xnwVmG/I/CsSzo9XozoCMxU0v8rgKHULux7uj...      False
# 7402  5z7gVMkY/xthDM9/jcfMbwKtR7j/355XcY/GD8Cz5bBy/w...      False
# 7404  NiINEr1M9mM1HGL63eI982E8NgfkAhNXa0XdneI1kp6Liv...      False
# 7406  ChDvK3+T38LwA+XzO+5z9cIdkvT7OmpHbaCB4pSiYb26rE...      False
#
#                    created_at              updated_at is_delete  deleted_at  \
# 35    2024-10-19 12:17:40.119 2024-10-19 12:17:40.119     False         NaN
# 4243  2024-10-19 16:07:57.979 2024-10-19 16:07:57.979     False         NaN
# 4296  2024-11-05 01:58:21.152 2024-11-05 01:58:21.152     False         NaN
# 4325   2024-10-14 11:42:00.38 2024-10-14 11:42:00.380     False         NaN
# 4351  2024-10-30 07:59:41.356 2024-10-30 07:59:41.356     False         NaN
# ...                       ...                     ...       ...         ...
# 7384  2024-09-29 14:30:20.591 2024-09-29 14:30:20.591     False         NaN
# 7400   2024-09-29 16:13:44.15 2024-09-29 16:13:44.150     False         NaN
# 7402  2024-10-09 09:31:35.512 2024-10-09 09:31:35.512     False         NaN
# 7404  2024-10-18 07:56:21.354 2024-10-18 07:56:21.354     False         NaN
# 7406  2024-10-26 21:43:00.153 2024-10-26 21:43:00.153     False         NaN
#
#       delete_reason                               user_id  \
# 35              NaN  873d3092-dae8-44a3-9d02-8226cbf354d6
# 4243            NaN  b29ecc96-43e4-4d5c-aa6c-9e55b9b1b3a6
# 4296            NaN  542d730c-2576-43f2-9538-bfd8ad142b15
# 4325            NaN  210cbe54-80d9-4ead-a355-fc155ee5f7d7
# 4351            NaN  4f9596a1-fb1c-4a1a-8ae5-070932035198
# ...             ...                                   ...
# 7384            NaN  31ad000b-fdfe-4b7b-b69a-2c65ff8587d6
# 7400            NaN  41ac9416-bb6e-4493-ac91-4694a6e263fc
# 7402            NaN  29d20e6e-c5a6-4385-ae88-d2192809dbb3
# 7404            NaN  fafa0a93-33e9-46e0-93c4-8d03a30cca50
# 7406            NaN  f6254161-3c1a-473b-a843-a63fa35ec282
#
#                             display_email settings
# 35    x8n8dtq5jh@privaterelay.appleid.com       {}
# 4243  gf8tvxd45f@privaterelay.appleid.com       {}
# 4296  hzqkxkbccr@privaterelay.appleid.com       {}
# 4325  dk5ykxcjnh@privaterelay.appleid.com       {}
# 4351  dhgvmr6rdq@privaterelay.appleid.com       {}
# ...                                   ...      ...
# 7384  44g5cvfbp9@privaterelay.appleid.com       {}
# 7400  6bqbxdnmtc@privaterelay.appleid.com       {}
# 7402                 dhsrudal@hanmail.net       {}
# 7404  xxf6wxqsr7@privaterelay.appleid.com       {}
# 7406           goodmanchoiyunho@gmail.com       {}
#
# [139 rows x 21 columns]
