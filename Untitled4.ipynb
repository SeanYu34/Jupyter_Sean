# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('/Users/mac/Downloads/[공구] 일정 신청 및 관리 시트 - 공구전체일정.csv')

# %%
df['상품명']
# Out:
#                          결제 번호  상품 번호        주문 번호                  결제 완료일  \
# 0     parma20250527105511iIOy0  51136  55801-54158 2025-05-27 10:55:35.478
# 1     parma202505271044579hHj3  50005  55798-54157 2025-05-27 10:45:18.128
# 2     parma20250527103622hs513  50004  55795-54156 2025-05-27 10:37:04.885
# 3     parma20250527083036hdAT9  50006  55794-54155 2025-05-27 08:30:53.066
# 4     parma20250527082058aXMq8  50004  55793-54154 2025-05-27 08:21:27.153
# ...                        ...    ...          ...                     ...
# 3823  parma20240925172751DghH1  50009  50007-50007 2024-09-25 17:27:51.577
# 3824  parma20240925172708CxYg8  50009  50006-50006 2024-09-25 17:27:08.194
# 3825  parma20240925133216CVxv5  50009  50005-50005 2024-09-25 13:32:16.307
# 3826  parma2024092310180885hK0  50000  50004-50004 2024-09-23 10:18:06.994
# 3827  parma20240920184127cDyU0  50000  50003-50003 2024-09-20 18:41:26.787
#
# ...
