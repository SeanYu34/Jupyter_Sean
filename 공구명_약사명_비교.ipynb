# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
import matplotlib.pyplot as plt
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('/Users/seanyu_mac/Downloads/public_admin_group_buy_info_export_2025-03-27_115213.csv')
df1 = pd.read_csv('/Users/seanyu_mac/Downloads/public_admin_profile_export_2025-03-27_115821.csv')

# %%
df1 = df1[['admin_id', 'pharmacy_name']]
temp_df = pd.merge(df, df1, on='admin_id', how='left')
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1359 non-null   int64
#  1   admin_id             1359 non-null   int64
#  2   product_id           1359 non-null   int64
#  3   shop_link            397 non-null    object
#  4   provider_fee         1359 non-null   int64
#  5   pb_fee               1359 non-null   float64
#  6   pharmacy_fee         1359 non-null   float64
#  7   tax_yn               1359 non-null   object
#  8   check_list           0 non-null      float64
#  9   product_option       1359 non-null   object
#  10  buy_start_date       1359 non-null   object
#  11  buy_end_date         1359 non-null   object
#  12  reg_dt               1359 non-null   object
#  13  del_yn               1359 non-null   object
#  14  check_status         1359 non-null   object
# ...

# %%
temp_df['show_product_name'].unique().tolist()
# Out:
# ['YDY 오큐클리어 800mgX60캡슐(48g)',
#  '더리틀스 비오틴 액상 콜라겐부스터',
#  nan,
#  'YDY 오큐클리어 ',
#  '테스트',
#  'YDY 파이토 레드큐민',
#  '비포락토 100 이지멜트 프로바이오틱스',
#  '나프라우드 셀이뮨 종합 멀티비타민 앤 미네랄',
#  '닥터체크 원퍼데이 맥스 알티지 오메가3',
#  '담백하루 키즈 알티지 오메가 츄 600 리뷰 이벤트 ',
#  '모바타 샴푸&트리트먼트&토닉&헤어세럼',
#  '트루엔 초임계 알티지오메가3',
#  'YDY 오큐클리어',
#  '닥터체크 원퍼데이 프리미엄 프로바이오틱스',
#  '팜트리 바이탈 라인&시카 톤업 베이스',
#  '닥터라인 헤모퀸즈',
#  '닥터체크 원퍼데이 트루 비타민C',
#  'YDY 액티브헴철',
#  '폴리케어 부스터',
#  'NMN',
#  '닥터라인 헤모퀸즈~',
#  '닥터체크 원퍼데이 맥스 초임계 알티지 오메가3',
#  '키즈 팡팡 쾌변젤리',
#  '안국건강 인생뷰티 히알루론산 비오틴',
#  '담백하루 초임계 알티지 오메가',
#  '닥터라인 마그네슘 다이렉트',
#  '테라큐민 슈퍼 플러스 100',
#  '위타민 D3K2츄어블 2000iu ',
#  'YDY 액티브비큐텐',
#  '더리틀스 면역 그린프로부스터',
#  '담백하루 노르딕 알티지 오메가 에센스',
#  '엘레나 스틱',
#  '닥터제안 비타포뮬러 퓨어 글루타치온',
#  '더리틀스 콜라겐부스터',
#  'YDY 퓨어 리포좀 비타민C',
#  '더리틀스 카테바나 슈가컷부스터',
#  '헬스베버리지 유기농 발사믹 IGP',
#  '나프라우드 큐로세틴 프로',
#  '트루엔키즈 샤르르 리포좀 비타민 C&D, 트루엔 메가 리포좀 비타민C 1000',
#  '코박사 엘더베리',
#  '트루엔 알티지오메가3 이지',
#  '트루엔파머스 정직한 수세미와 작두콩',
#  '비포락토 시리즈 (100 & 덴틱스&베이비&키즈&펫프리미엄)',
# ...

# %%
temp_df[temp_df['group_buy_title'].isna()]
# Out:
#         id  admin_id  product_id  \
# 0       86        56       25123
# 1      150        53       26331
# 2       10        16        1005
# 3       36        16       25123
# 4      621        16       35208
# ...    ...       ...         ...
# 1353  1128        52       26458
# 1354  1328        52       26759
# 1355  1236        52       25123
# 1356  1280        52       35547
# 1358  1346        52       35611
#
#                                               shop_link  provider_fee  pb_fee  \
# 0                                                   테스트           100     0.0
# 1     https://brand.naver.com/thelittles/products/90...           100     0.0
# 2                                                   테스트           100     0.0
# 3                                                  TEST           100     0.0
# 4     https://smartstore.naver.com/thejoeunevent/pro...           100     0.0
# ...                                                 ...           ...     ...
# ...

# %%
'릴리약사' in temp_df['group_buy_title'].unique().tolist()
# Out:
# False

# %%
temp_df['group_buy_title'].unique()
# Out:
# array([nan, '모바타 샴푸&트리트먼트&토닉&헤어세럼 공구 오픈', '트루엔 초임계 알티지오메가3 공구 오픈',
#        '트루엔 양태반 글루타치온 뽀얀젤리 공구 오픈', '키즈 팡팡 쾌변젤리 공구 오픈',
#        '안국건강 인생뷰티 히알루론산 비오틴 공구 오픈', '담백하루 초임계 알티지 오메가 공구 오픈',
#        '닥터라인 마그네슘 다이렉트 공구 오픈', 'YDY 폴라 초임계 오메가3 폴라리스 RTG 30캡 공구 오픈',
#        '트루엔 리포좀 비타민C 공구 오픈', '더리틀스 면역 그린프로부스터 공구 오픈', '엘레나 스틱 공구 오픈',
#        '닥터제안 비타포뮬러 퓨어 글루타치온 공구 오픈', '더리틀스 콜라겐부스터 공구 오픈',
#        '더리틀스 카테바나 슈가컷부스터 공구 오픈', '헬스베버리지 유기농 발사믹 IGP 공구 오픈',
#        '나프라우드 큐로세틴 프로 공구 오픈', '코박사 엘더베리 공구 오픈', '트루엔 알티지오메가3 이지 공구 오픈',
#        '투퍼데이 액티브 멀티비타민 공구 오픈', '위타민 알티지 오메가3 미니 공구 오픈',
#        '일동제약 지큐랩 장건강 포스트솔루션 공구 오픈', '더좋은 진짜 진하고 맛있는 양배추 15ml x 30포 공구 오픈',
#        'YDY 프로바이오 에스엘비(SLB) 공구 오픈',
#        '담백하루 초임계 알티지 오메가에센스 1000 (밴드용) 공구 오픈', '랩트리션 그로우업 플러스 공구 오픈',
#        '한독 테라큐민 맥스 60 공구 오픈', 'YDY 폴라 초임계 오메가3 공구 오픈', 'YDY 액티브비큐텐 공구 오픈',
#        'YDY 파이토 레드큐민 공구 오픈', 'YDY 코랄칼마디 1,200mg x 60정 공구 오픈',
#        '더좋은 프로틴 포뮬라 공구 오픈', '닥터제안 비타포뮬러 프리프로바이오틱스 공구 오픈',
# ...
